# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('/Users/Belal/opencv/data/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/Users/Belal/opencv/data/haarcascades/haarcascade_eye.xml')

smile_cascade = cv2.CascadeClassifier('/Users/Belal/opencv/data/haarcascades/haarcascade_smile.xml')

# %%
#img = cv2.imread("/Users/Belal/Desktop/dat_face.jpg")
img = cv2.imread('../sample_data/')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
plt.imshow(img[:,:,::-1])
plt.show()

# %%
im = cv2.imread("/Users/Belal/Desktop/dat_face.jpg")
imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 127, 255, 0)
im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
plt.imshow("img", im2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c33d4d387a42> in <module>()
#       3 ret, thresh = cv2.threshold(imgray, 127, 255, 0)
#       4 im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# ----> 5 plt.imshow("img", im2)
#       6 plt.show()
#
# //anaconda/envs/opencv/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# ...

# %%
cnt = contours[4]
img = cv2.drawContours(im, [cnt], 0, (0,255,0), 3)
plt.imshow("img", img[:,:,::-1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-e5871170a8d6> in <module>()
#       1 cnt = contours[4]
#       2 img = cv2.drawContours(im, [cnt], 0, (0,255,0), 3)
# ----> 3 plt.imshow("img", img)
#       4 plt.show
#
# //anaconda/envs/opencv/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# //anaconda/envs/opencv/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
# Out:
# array([[[ 95,  65,  13],
#         [ 97,  67,  13],
#         [ 97,  71,  14],
#         ...,
#         [ 88,  72,  38],
#         [ 81,  67,  32],
#         [ 79,  65,  30]],
#
#        [[ 93,  63,  13],
#         [ 97,  67,  15],
#         [ 94,  67,  12],
#         ...,
#         [ 89,  73,  40],
#         [ 85,  69,  36],
#         [ 84,  68,  35]],
#
#        [[ 96,  66,  16],
#         [ 91,  63,  13],
#         [ 91,  64,  11],
#         ...,
#         [ 88,  71,  43],
#         [ 88,  71,  41],
#         [ 90,  73,  43]],
#
#        ...,
#        [[ 45,   9,  13],
#         [ 44,   9,  13],
#         [ 39,   9,  11],
#         ...,
#         [ 90,  56,  89],
#         [ 91,  60,  92],
#         [ 91,  60,  92]],
#
#        [[ 47,  10,  17],
#         [ 45,  10,  16],
#         [ 39,   8,  13],
#         ...,
#         [ 90,  58,  95],
#         [ 90,  58,  97],
#         [ 87,  57,  95]],
#
#        [[ 48,  11,  19],
#         [ 42,   9,  16],
#         [ 36,   7,  11],
# ...
