# %%
import numpy as np
import pandas as pd
import string

# %%
bu_words = ["again",
"also",
"ask",
"all",
"because",
"boy",
"but",
"can",
"come",
"deaf",
"different",
"done",
"drink",
"drive",
"eat",
"speak",
"speech (as in giving a speech)",
"excuse me",
"family",
"father",
"few",
"fine",
"fingerspell",
"food",
"for",
"friend",
"get",
"girl",
"give",
"good",
"have",
"he",
"hearing",
"hello",
"help",
"home",
"how",
"if",
"Internet",
"know",
"like (feeling)",
"little",
"live",
"locate",
"man",
"many",
"me",
"meet",
"more",
"my",
"name",
"need",
"new",
"no",
"not",
"ok",
"old",
"other",
"people",
"play",
"please",
"remember",
"same",
"say",
"school",
"see",
"she",
"should",
"signing",
"slow",
"some",
"sorry",
"take",
"tell",
"texting",
"thank you",
"that",
"their",
"they",
"think",
"time",
"tired",
"toilet",
"understand",
"use",
"wait",
"water",
"what",
"when",
"where",
"which",
"who",
"why",
"will",
"with",
"woman",
"work",
"write",
"yes",
"you",
"your",]

# %% [markdown]
# ### Generate list of web links to scrape for words + alphabet

# %%
word_url = []
for word in bu_words:
    bu_string = "http://secrets.rutgers.edu/dai/queryPages/search/result.php?type=whole&key=HOW&variant_name=HOW&demonstrator=All&is_main=1"
    word_url.append(bu_string.replace("HOW", word))

# %%
az_url = []
for letter in string.ascii_uppercase:
    bu_string = "http://secrets.rutgers.edu/dai/queryPages/search/result.php?type=whole&key=HOW&variant_name=HOW&demonstrator=All&is_main=1"
    az_url.append(bu_string.replace("HOW", letter))

# %% [markdown]
# ### Extract href links from all websites

# %%
# ONE WAY to do it!
from urllib.request import urlopen
import re

az_all = []
az_len = []

for url in az_url:
    #connect to a URL
    website = urlopen(url)

    #read html code
    html = website.read().decode('utf-8')

    #use re.findall to get all the links)
    linkzz = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', html)
    az_len.append(len(linkzz))
    az_all.append(linkzz)

# %%
############# BEAUTIFUL SOUP
###########################
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
###Extract href for words
word_dl = []
word_len = []
count = 0

for url in word_url:
    
    conn = urlopen(url)
    html = conn.read()
    soup = BeautifulSoup(html, 'lxml')
    word_links = soup.find_all('a')
    word_len.append(len(word_links))
    
    for tag in word_links:
        link = tag.get('href',None)
        #if link is not None:
        word_dl.append((link, bu_words[count]))
    
    count += 1

# %%
#remove initial characters

final_words  =[(word[1], word[0][22:]) for word in word_dl]

# %%
#check all are 'mov'

check=[]
for word in final_words:
    check.append((word[1]).endswith('mov'))
    
sum(check) == len(final_words)

# %%
###Extract href for letters
az_dl = []
az_len = []
letters = string.ascii_uppercase
count = 0

for url in az_url:
    
    conn = urlopen(url)
    html = conn.read()
    soup = BeautifulSoup(html, 'lxml')
    az_links = soup.find_all('a')
    az_len.append(len(az_links))
    
    for tag in az_links:
        link = tag.get('href',None)
        #if link is not None:
        az_dl.append((link, letters[count]))
        

        count += 1

# %%
final_az  =[(letter[1], letter[0][22:]) for letter in az_dl]

# %%
final_az

# %%
#check all are 'mov'

check=[]
for letter in final_az:
    check.append(letter.endswith('mov'))
    
sum(check) == len(final_az)
# Out:
# True

# %% [markdown]
# ### Download videos

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.11.2-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 614kB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.11.2

# %%
import os
import logging
import hashlib
from io import BytesIO

from PIL import Image
import requests
from urllib.request import urlretrieve

logger = logging.getLogger(__name__)


def hash_url(url):
    hash_object = hashlib.md5(url.encode())
    return hash_object.hexdigest()


def download_image(url, path, timeout=0.5):
    filename = os.path.join(path, hash_url(url) + ".mov")
    if not os.path.exists(filename):
        try:
            path, _ = urlretrieve(url, filename)
        except Exception as e:
            print('Error: {}'.format(e))
            print('For url: {}'.format(url))
            path = ''
    else:
        print("duplicate, skipping!")
    return path

# %%
# Download letters

from tqdm import tqdm_notebook 
import os
for l, url in tqdm_notebook(final_az):
    path = os.path.join("../train_data/asllvd/", l)
    os.makedirs(path, exist_ok=True)
    download_image(url, path)
# Download letters
# Out:
# ../train_data/asllvd/A/bfb43ec9e036933cc824865245a51cb8.mov
#
# ../train_data/asllvd/A/002e57cefcaf594e35bec8c3c3bd3afe.mov
# ../train_data/asllvd/A/b273dcefbb0149030503d40e4768c6bf.mov
# ../train_data/asllvd/A/002e57cefcaf594e35bec8c3c3bd3afe.mov
# afa
# ../train_data/asllvd/A/2e7f75b1ef42a593b8e9a2ab3bfecc9d.mov
# ../train_data/asllvd/A/002e57cefcaf594e35bec8c3c3bd3afe.mov
# afa
# ../train_data/asllvd/A/ee3fbb978155b0ed7c19fc1678aaf6af.mov
# ../train_data/asllvd/A/002e57cefcaf594e35bec8c3c3bd3afe.mov
# afa
# ../train_data/asllvd/B/552675d7585b99f00d1e1e96cf352b81.mov
# ../train_data/asllvd/B/2870e6efa3da2ce8821e0fc9d238534d.mov
# ../train_data/asllvd/B/d0ade8ea36d35a346ec3c0be471cf66d.mov
# ../train_data/asllvd/B/2870e6efa3da2ce8821e0fc9d238534d.mov
# afa
# ../train_data/asllvd/B/c62300ae77e1ef56792bdaebdc8ced22.mov
# ../train_data/asllvd/B/2870e6efa3da2ce8821e0fc9d238534d.mov
# afa
# ../train_data/asllvd/B/5145b16872bfd0a763a49a8b4073e60a.mov
# ../train_data/asllvd/B/2870e6efa3da2ce8821e0fc9d238534d.mov
# afa
# ../train_data/asllvd/C/4ddd9ae5ad0c732ca71878b81d8b7831.mov
# ../train_data/asllvd/C/c0083ab6b78ffb43cb0ac8d700c10211.mov
# ../train_data/asllvd/C/be8f4eaea985f366053462a96d25e685.mov
# ../train_data/asllvd/C/c0083ab6b78ffb43cb0ac8d700c10211.mov
# afa
# ../train_data/asllvd/C/567a754ee196056645b598f6b38f0bde.mov
# ../train_data/asllvd/C/c0083ab6b78ffb43cb0ac8d700c10211.mov
# afa
# ../train_data/asllvd/C/9e4135442347038096355d05366ee11b.mov
# ../train_data/asllvd/C/c0083ab6b78ffb43cb0ac8d700c10211.mov
# afa
# ../train_data/asllvd/D/e69f60859316b524a10da413da7d7955.mov
# ../train_data/asllvd/D/b3ff8c0077b5ce1817842695e3344838.mov
# ../train_data/asllvd/D/b7ca17ad49acefa9ca0ac7a827262fda.mov
# ../train_data/asllvd/D/b3ff8c0077b5ce1817842695e3344838.mov
# afa
# ../train_data/asllvd/D/28bb1558d33164134b0e72bd216f9500.mov
# ../train_data/asllvd/D/b3ff8c0077b5ce1817842695e3344838.mov
# afa
# ../train_data/asllvd/D/83ba669a4c87ff372b9fe819f3eb2e0a.mov
# ../train_data/asllvd/D/b3ff8c0077b5ce1817842695e3344838.mov
# afa
# ../train_data/asllvd/E/488d0a17734db149559da94e91a23bd1.mov
# ../train_data/asllvd/E/4c7474e3593a9fe2f8645175ad65a96c.mov
# ../train_data/asllvd/E/08aa42b4f92ce74ec795655c97c1a8d1.mov
# ../train_data/asllvd/E/4c7474e3593a9fe2f8645175ad65a96c.mov
# afa
# ../train_data/asllvd/E/b5e98ac45c3469d54ffd8d32fa12c801.mov
# ../train_data/asllvd/E/4c7474e3593a9fe2f8645175ad65a96c.mov
# afa
# ../train_data/asllvd/F/afaff2576a371f67aa1416b9ee4714e0.mov
# ../train_data/asllvd/F/6d3aa9acc0942a744f5c72abf0d82caf.mov
# ../train_data/asllvd/F/4afad8914b3accf0c212d9988c90bc4c.mov
# ../train_data/asllvd/F/6d3aa9acc0942a744f5c72abf0d82caf.mov
# afa
# ../train_data/asllvd/F/90cc51e37b03530d1a16a03ff71d3e93.mov
# ../train_data/asllvd/F/6d3aa9acc0942a744f5c72abf0d82caf.mov
# afa
# ../train_data/asllvd/F/f3d5f50c8236102cc61cb4aaf4115bab.mov
# ../train_data/asllvd/F/6d3aa9acc0942a744f5c72abf0d82caf.mov
# afa
# ../train_data/asllvd/G/18a5d53b2138152c455a4629ab13174e.mov
# ../train_data/asllvd/G/389a5804f0625e807444085b3b66ce7a.mov
# ../train_data/asllvd/G/15fdac187965eca2e39fff9010877753.mov
# ../train_data/asllvd/G/389a5804f0625e807444085b3b66ce7a.mov
# afa
# ../train_data/asllvd/G/f5c60866dc0a3aad628ac9eedef39956.mov
# ../train_data/asllvd/G/389a5804f0625e807444085b3b66ce7a.mov
# afa
# ../train_data/asllvd/G/24d815d6fe697dabdfae1daf60b3858c.mov
# ../train_data/asllvd/G/389a5804f0625e807444085b3b66ce7a.mov
# afa
# ../train_data/asllvd/H/fa76110f76c28793692b88985aeee875.mov
# ../train_data/asllvd/H/6aa81cd8a45de7efb3364855f3ffcbf8.mov
# ../train_data/asllvd/H/6ac28fc57cd3a3f81bbc788d9d6df945.mov
# ../train_data/asllvd/H/6aa81cd8a45de7efb3364855f3ffcbf8.mov
# afa
# ../train_data/asllvd/H/92651360c397a382310585113d568a15.mov
# ../train_data/asllvd/H/6aa81cd8a45de7efb3364855f3ffcbf8.mov
# afa
# ../train_data/asllvd/H/f92bb0783971ecc2b2644c95f47f07c6.mov
# ../train_data/asllvd/H/6aa81cd8a45de7efb3364855f3ffcbf8.mov
# afa
# ../train_data/asllvd/I/4a19b102430557abc7cb5e3aad9c7b59.mov
# ../train_data/asllvd/I/2652554fda84998bb56ff178ac83cc6f.mov
# ../train_data/asllvd/I/30c919d3197e51c3aa78f04a9c47c6cf.mov
# ../train_data/asllvd/I/2652554fda84998bb56ff178ac83cc6f.mov
# afa
# ../train_data/asllvd/I/234c74d33616cf90c0bfa23ed0e9e65d.mov
# ../train_data/asllvd/I/2652554fda84998bb56ff178ac83cc6f.mov
# afa
# ../train_data/asllvd/J/87bede55414d0dc41b74b8dbed0f5e93.mov
# ../train_data/asllvd/J/cc039f8d3140b87427ca296fa0297001.mov
# ../train_data/asllvd/J/5e96e9fdbda1f7b757d222d740b6a21c.mov
# ../train_data/asllvd/J/cc039f8d3140b87427ca296fa0297001.mov
# afa
# ../train_data/asllvd/J/0cc68b9398ba6297379e581640d7ade0.mov
# ../train_data/asllvd/J/cc039f8d3140b87427ca296fa0297001.mov
# afa
# ../train_data/asllvd/K/4ce28de1485271c97c4304c09059165a.mov
# ../train_data/asllvd/K/a5d5bcfedcd09eb8f2aae6bd7e710649.mov
# ../train_data/asllvd/K/ecfca739232a0f715ed7f5318ac5d209.mov
# ../train_data/asllvd/K/a5d5bcfedcd09eb8f2aae6bd7e710649.mov
# afa
# ../train_data/asllvd/K/a5c96892d4f01dccaee2320e40c315a6.mov
# ../train_data/asllvd/K/a5d5bcfedcd09eb8f2aae6bd7e710649.mov
# afa
# ../train_data/asllvd/K/a2d079603e0928fab2c12767e83c10ac.mov
# ../train_data/asllvd/K/a5d5bcfedcd09eb8f2aae6bd7e710649.mov
# afa
# ../train_data/asllvd/L/71349beae033033bfff294043c5f553e.mov
# ../train_data/asllvd/L/aeb4a5b3836fb9904f563016896f7146.mov
# ../train_data/asllvd/L/c3ac113c8ee389ef6b3ea3709111d769.mov
# ../train_data/asllvd/L/aeb4a5b3836fb9904f563016896f7146.mov
# afa
# ../train_data/asllvd/L/3bdd68340249967f924d8ff8f94e2279.mov
# ../train_data/asllvd/L/aeb4a5b3836fb9904f563016896f7146.mov
# afa
# ../train_data/asllvd/L/33a32d3556d752153b7c31b646c4b98e.mov
# ../train_data/asllvd/L/aeb4a5b3836fb9904f563016896f7146.mov
# afa
# ../train_data/asllvd/M/cab6cb54d908880d81c9d48df6243d35.mov
# ../train_data/asllvd/M/fe6c484ef69a660492585870063eea25.mov
# ../train_data/asllvd/M/12d33f611e07187b1db6279729c0aa97.mov
# ../train_data/asllvd/M/fe6c484ef69a660492585870063eea25.mov
# afa
# ../train_data/asllvd/M/21e10e478596b1b759e1738f72c3d7cf.mov
# ../train_data/asllvd/M/fe6c484ef69a660492585870063eea25.mov
# afa
# ../train_data/asllvd/M/09001446113528e451b6cae6f0d29d74.mov
# ../train_data/asllvd/M/fe6c484ef69a660492585870063eea25.mov
# afa
# ../train_data/asllvd/N/6690de10760d739adf887e0992d546e1.mov
# ../train_data/asllvd/N/ffe81878e482d9e68ae1dc8e554d7fb7.mov
# ../train_data/asllvd/N/eaa85d3fc94e998334064e7804ae3f0f.mov
# ../train_data/asllvd/N/ffe81878e482d9e68ae1dc8e554d7fb7.mov
# afa
# ../train_data/asllvd/O/7793ff08342f86adb4d1f21536e62d0b.mov
# ../train_data/asllvd/O/b782ac1b1608ae8cbdea7d30d620a6fb.mov
# ../train_data/asllvd/O/86bcd123e653e107895b6154e4e5d68f.mov
# ../train_data/asllvd/O/b782ac1b1608ae8cbdea7d30d620a6fb.mov
# afa
# ../train_data/asllvd/P/e943df5eed8b6d77e91cdc2f33105d26.mov
# ../train_data/asllvd/P/1ad97b14a3311c92262c957b9de743e3.mov
# ../train_data/asllvd/P/be36134b74798ccc0a248f10fc41d9d2.mov
# ../train_data/asllvd/P/1ad97b14a3311c92262c957b9de743e3.mov
# afa
# ../train_data/asllvd/Q/95f2efcc08073d960a333afec5b7e2ed.mov
# ../train_data/asllvd/Q/2a0c724df7f185bf421232b6980b3ed3.mov
# ../train_data/asllvd/Q/a723e1f238afe023ee6047ffb5aa480e.mov
# ../train_data/asllvd/Q/2a0c724df7f185bf421232b6980b3ed3.mov
# afa
# ../train_data/asllvd/R/c8c94e4e8d74b45fb50850f344068ea4.mov
# ../train_data/asllvd/R/fe52768e9177f4a286d99408da8cc7bf.mov
# ../train_data/asllvd/R/33d0661d66e83fee90dfa17be27f8551.mov
# ../train_data/asllvd/R/fe52768e9177f4a286d99408da8cc7bf.mov
# afa
# ../train_data/asllvd/S/0df10bf1336ce259ca44145ab4cda93a.mov
# ../train_data/asllvd/S/6de817319dcb649703c3cba07e87b8e5.mov
# ../train_data/asllvd/S/912073e4e3b538d0298c1e8c7872cdb7.mov
# ../train_data/asllvd/S/6de817319dcb649703c3cba07e87b8e5.mov
# afa
# ../train_data/asllvd/T/4316d415c31087391bebd915b9de13b9.mov
# ../train_data/asllvd/T/9721069a2842131c6114186cbf3f316a.mov
# ../train_data/asllvd/T/64f435eca6b0fa88e25714e2c8841968.mov
# ../train_data/asllvd/T/9721069a2842131c6114186cbf3f316a.mov
# afa
# ../train_data/asllvd/U/525bea5707b0e221ca0b949be470bcb8.mov
# ../train_data/asllvd/U/0a6d301255014fb673b85f24bba034e0.mov
# ../train_data/asllvd/U/48d5f4c3637d8ca81ee104d72c0caf4a.mov
# ../train_data/asllvd/U/0a6d301255014fb673b85f24bba034e0.mov
# afa
# ../train_data/asllvd/V/0f37440a757e9b1d7e37b13ad6448277.mov
# ../train_data/asllvd/V/9516b31f8b7170f18ac63dd9a66a4b7f.mov
# ../train_data/asllvd/V/080a4c3e84cb9f273637df46a382317c.mov
# ../train_data/asllvd/V/9516b31f8b7170f18ac63dd9a66a4b7f.mov
# afa
# ../train_data/asllvd/W/2853d09e20d49f7f4bc1fb2647035af2.mov
# ../train_data/asllvd/W/ce9c7b76e7c8eb4e67559ce7a2d839de.mov
# ../train_data/asllvd/W/a4db368eeeafa450e3d93849ad5e4f7c.mov
# ../train_data/asllvd/W/ce9c7b76e7c8eb4e67559ce7a2d839de.mov
# afa
# ../train_data/asllvd/X/603113d259de5e85847e443542374c38.mov
# ../train_data/asllvd/X/d7fd06ebeba4eff209467647e20522bd.mov
# ../train_data/asllvd/X/37a9234e09ce0792e976f4afe9f25edb.mov
# ../train_data/asllvd/X/d7fd06ebeba4eff209467647e20522bd.mov
# afa
# ../train_data/asllvd/Y/dffb936fcef79a893bc03426706cf2ce.mov
# ../train_data/asllvd/Y/b02b3224c1abb9bb2cf9e6eac0709311.mov
# ../train_data/asllvd/Y/c59f966dcfee58d7de2dc762bcbcdaea.mov
# ../train_data/asllvd/Y/b02b3224c1abb9bb2cf9e6eac0709311.mov
# afa
# ../train_data/asllvd/Z/e08cc20ce300b5e70e4e25e5de63fa84.mov
# ../train_data/asllvd/Z/27d724d66bc725b868855bd6060a894c.mov
# ../train_data/asllvd/Z/fabbaee5922c6fd3126d3976aa847777.mov
# ../train_data/asllvd/Z/27d724d66bc725b868855bd6060a894c.mov
# afa

# %%
# Download words

from tqdm import tqdm_notebook 
import os
for l, url in tqdm_notebook(final_words):
    path = os.path.join("../train_data/asllvd/", l)
    os.makedirs(path, exist_ok=True)
    download_image(url, path)
# Out:
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
# duplicate, skipping!
